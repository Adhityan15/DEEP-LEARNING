# %%
# !pip install openai-whisper sounddevice scipy ffmpeg-python
# Out:
# ...
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ------------------------ ------------- 524.3/803.2 kB 8.5 MB/s eta 0:00:01
#      ---------------------------------------- 803.2/803.2 kB 8.7 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 19.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    - -------------------------------------- 1.3/38.1 MB 8.4 MB/s eta 0:00:05
# ...

# %%
import sounddevice as sd
from scipy.io.wavfile import write

fs = 44100  # Sample rate
seconds = 5  # Recording duration

print("Start speaking... 🎤")
audio = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
sd.wait()

write("recorded.wav", fs, audio)

print("Recording saved as recorded.wav ✅")
# Out:
# Start speaking... 🎤
# Recording saved as recorded.wav ✅

# %%
import whisper

model = whisper.load_model("base")  # first time downloads model
print("Model loaded 😌")
# Out:
# Model loaded 😌

# %%
model = whisper.load_model("tiny")

# %%
result = model.transcribe("recorded.wav")
print("You said:", result["text"])
# Out:
# C:\Users\adhit\AppData\Local\Programs\Python\Python311\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# You said:  And he tuned deep learning mini project.

# %%
file_path = "recorded.wav"  # change to your file if needed

result = model.transcribe(file_path)
print("Converted Text:", result["text"])
# Out:
# Converted Text:  And he tuned deep learning mini project.

# %%
# !ffmpeg -version

# %%
# !pip uninstall tensorflow -y
# !pip install torch
# !pip install transformers --upgrade
# !pip install protobuf==3.20.3
# Out:
# Found existing installation: tensorflow 2.21.0
# Uninstalling tensorflow-2.21.0:
#   Successfully uninstalled tensorflow-2.21.0
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\adhit\AppData\Local\Temp\pip-uninstall-on282q10'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\adhit\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\~latform'.
# You can safely remove it manually.
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/10.2 MB 14.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.5/10.2 MB 16.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.5/10.2 MB 10.2 MB/s eta 0:00:01
# ...

# %%
# -------------------------------
# 📦 INSTALL (Run once)
# -------------------------------
# !pip uninstall tensorflow -y
# !pip install openai-whisper sounddevice scipy transformers torch protobuf==3.20.3

# -------------------------------
# 📚 IMPORTS
# -------------------------------
import sounddevice as sd
from scipy.io.wavfile import write
import whisper
from transformers import pipeline
import torch

# -------------------------------
# 🎤 RECORD AUDIO
# -------------------------------
fs = 44100
seconds = 5

print("🎤 Speak now...")
audio = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
sd.wait()

file_name = "recorded.wav"
write(file_name, fs, audio)

print("✅ Audio recorded and saved")

# -------------------------------
# 🧠 SPEECH TO TEXT (WHISPER)
# -------------------------------
print("⏳ Loading Whisper model...")
model = whisper.load_model("base")   # use "tiny" if slow

result = model.transcribe(file_name)
text = result["text"]

print("\n📝 Transcribed Text:")
print(text)

# -------------------------------
# 🤖 LLM (TEXT PROCESSING)
# -------------------------------
print("\n🤖 Loading LLM...")

llm = pipeline("text-generation", model="distilgpt2", framework="pt")

prompt = "Summarize this speech clearly:\n" + text

output = llm(prompt, max_length=80, num_return_sequences=1)

print("\n✨ LLM Output:")
print(output[0]['generated_text'])
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 13
#      11 from scipy.io.wavfile import write
#      12 import whisper
# ---> 13 from transformers import pipeline
#      14 import torch
#      16 # -------------------------------
#      17 # 🎤 RECORD AUDIO
#      18 # -------------------------------
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:2045, in _LazyModule.__getattr__(self, name)
#    2043 elif name in self._class_to_module.keys():
#    2044     try:
# -> 2045         module = self._get_module(self._class_to_module[name])
#    2046         value = getattr(module, name)
# ...

# %%
# !pip install --upgrade huggingface_hub
# !pip install --upgrade transformers
# Out:
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline
print("Transformers working 😏")
# Out:
# Transformers working 😏

# %%
# -------------------------------
# 📚 IMPORTS
# -------------------------------
import sounddevice as sd
from scipy.io.wavfile import write
import whisper
from transformers import pipeline

# -------------------------------
# 🎤 RECORD AUDIO
# -------------------------------
fs = 44100
seconds = 5

print("🎤 Speak now...")
audio = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
sd.wait()

file_name = "recorded.wav"
write(file_name, fs, audio)

print("✅ Audio recorded")

# -------------------------------
# 🧠 SPEECH TO TEXT
# -------------------------------
print("⏳ Loading Whisper...")
model = whisper.load_model("base")

result = model.transcribe(file_name)
text = result["text"]

print("\n📝 Transcribed Text:")
print(text)

# -------------------------------
# 🤖 LLM (SUMMARIZATION - CLEAN)
# -------------------------------
print("\n🤖 Generating Summary...")

llm = pipeline("text-generation", model="distilgpt2")

prompt = f"Summarize the following text in one sentence:\n{text}\nSummary:"

output = llm(prompt, max_length=60, num_return_sequences=1)

# Clean output
generated = output[0]['generated_text']

summary = generated.split("Summary:")[-1].strip()

print("\n✨ Summary Output:")
print(summary)
# Out:
# 🎤 Speak now...
# ✅ Audio recorded
# ⏳ Loading Whisper...
#
# 📝 Transcribed Text:
#  Hello, my name is Adityan. I am a student of Bunny...
#
# 🤖 Generating Summary...
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# C:\Users\adhit\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\adhit\.cache\huggingface\hub\models--distilgpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
